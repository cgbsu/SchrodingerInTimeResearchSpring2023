# %%
# %matplotlib widget

# %%
from libschrodinger import *

# %%
import numpy as np

# %%
import cupy as cp

# %%
caseName : str = "WithCg"

# %%
math = cp
spatialStep : float = .05
length : float = 8
temporalStep : float = (spatialStep ** 2) / 4
courantNumber : float = 1.0
pointCount : int = int(length / spatialStep)
potentialHeight : float = 200
print("Point Count: ", pointCount)
packetStartX : float = 1 / 5
packetStartY : float = 1 / 2
packetStandardDeviation : float = .5
packetWaveNumber : float = -15 * np.pi
barrierWidth : float = .6 / length

frameCount : int = 1000

tolerence = 1e-5
# Out:
# Point Count:  160

# %%
assert (temporalStep / spatialStep) <= courantNumber
profile = SimulationProfile(
        makeLinspaceGrid(pointCount, length, 2, False, float, math), 
        lambda position : makeWavePacket(
                position, 
                packetStartX * length, 
                packetStartY * length, 
                spatialStep, 
                packetStandardDeviation, 
                packetWaveNumber, 
                math
            ), 
        lambda position, time : tunnelCase(
                position, 
                length / 2 - barrierWidth, 
                barrierWidth * length, 
                potentialHeight
            ), 
        temporalStep, 
        spatialStep, 
        gpuAccelerated = True, 
        edgeBound = True, 
        constantPotential = True, 
        defaultMatrixSolveMethod = lambda profile, operator, indepednantTerms : solveMatrixApproximate(
                        profile, 
                        operator, 
                        indepednantTerms, 
                        tolerence
                    )
    )
simulator = Simulator(profile)
log = simulator.simulate(frameCount, True, True, True)
# Out:
# [====================================================================================================]
# [----------------------------------------------------------------------------------------------------]
# Total Time:  9.271441468998091
# Frames Per Second:  119.01787365147968

# %%
probabilities, probabilityDecibles = simulator.processProbabilities()

# %%
potentialAnimation = animateImages(
        length, 
        simulator.potentials, 
        10, 
        0, 
        potentialHeight, 
        colorMap = "hot"
    )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
waveAnimation = animateImages(
        length, 
        simulator.probabilities, 
        10, 
        0, 
        math.max(simulator.probabilities), 
        [length / 2 - barrierWidth, barrierWidth, length / 2 + barrierWidth], 
        [0, 1, 0], 
        colorMap = "hot"
    )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
waveAnimation.save(caseName + ".gif")

# %%
potentialAnimation.save(caseName + "Potential.gif")

# %%
unknownStepMatrix = simulator.createNextStepMatrix(simulator.potentials[-1])

# %%
unknownStepMatrix.todense()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 unknownStepMatrix.todense()
#
# File /opt/conda/lib/python3.10/site-packages/cupyx/scipy/sparse/_base.py:551, in spmatrix.todense(self, order, out)
#     549 def todense(self, order=None, out=None):
#     550     """Return a dense matrix representation of this matrix."""
# --> 551     return self.toarray(order=order, out=out)
#
# File /opt/conda/lib/python3.10/site-packages/cupyx/scipy/sparse/_dia.py:138, in dia_matrix.toarray(self, order, out)
#     136 def toarray(self, order=None, out=None):
#     137     """Returns a dense matrix representing the same value."""
# --> 138     return self.tocsc().toarray(order=order, out=out)
#
# File /opt/conda/lib/python3.10/site-packages/cupyx/scipy/sparse/_csc.py:224, in csc_matrix.toarray(self, order, out)
#     220 x.sum_duplicates()
#     221 if (cusparse.check_availability('sparseToDense')
#     222         and (not runtime.is_hip or x.nnz > 0)):
#     223     # On HIP, nnz=0 is problematic as of ROCm 4.2.0
# --> 224     y = cusparse.sparseToDense(x)
#     225     if order == 'F':
#     226         return y
#
# File /opt/conda/lib/python3.10/site-packages/cupy/cusparse.py:1816, in sparseToDense(x, out)
#    1814 assert dtype.char in 'fdFD'
#    1815 if out is None:
# -> 1816     out = _cupy.zeros(x.shape, dtype=dtype, order='F')
#    1817 else:
#    1818     assert out.flags.f_contiguous
#
# File /opt/conda/lib/python3.10/site-packages/cupy/_creation/basic.py:211, in zeros(shape, dtype, order)
#     196 def zeros(shape, dtype=float, order='C'):
#     197     """Returns a new array of given shape and dtype, filled with zeros.
#     198
#     199     Args:
#    (...)
#     209
#     210     """
# --> 211     a = cupy.ndarray(shape, dtype, order=order)
#     212     a.data.memset_async(0, a.nbytes)
#     213     return a
#
# File cupy/_core/core.pyx:136, in cupy._core.core.ndarray.__new__()
#
# File cupy/_core/core.pyx:224, in cupy._core.core._ndarray_base._init()
#
# File cupy/cuda/memory.pyx:742, in cupy.cuda.memory.alloc()
#
# File cupy/cuda/memory.pyx:1419, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1440, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1120, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1141, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc()
#
# File cupy/cuda/memory.pyx:1379, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc()
#
# OutOfMemoryError: Out of memory allocating 9,971,220,992 bytes (allocated so far: 864,635,392 bytes).

# %%
knownStepMatrix = simulator.createCurrentStepMatrix(simulator.potentials[-1])

# %%
knownStepMatrix.todense()
