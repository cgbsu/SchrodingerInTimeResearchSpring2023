# %%
# %matplotlib widget

# %%
from crank_nicolson_2d import *

# %%
import numpy as np

# %%
import scipy as sp

# %%
def tunnelCase(position, where, width, potential = 1): 
    return np.where(
            (position.x > where) & (position.x < (where + width)), 
            potential, 
            0, 
        )

# %%
def hydrogenAtom(position, potential, bottom = 1): 
    return potential / np.sqrt(
            (position.x / 2) ** 2 \
            + (position.y / 2) ** 2 \
            + bottom ** 2 \
        )

# %%
def doubleSlit(position, where, width, slitHeight, gapHeight, potential = 1, math=np): 
    totalY = math.max(position.y)
    return math.where(
            (position.x > where) & (position.x < (where + width)) 
                    & ( \
                            (position.y > ((totalY / 2) + (gapHeight + slitHeight))) \
                            | (position.y < ((totalY / 2) - (gapHeight + slitHeight))) \
                            | ( \
                               (position.y > ((totalY / 2) - gapHeight)) \
                               & (position.y < ((totalY / 2) + gapHeight)) \
                              )
                      ), 
            potential, 
            0, 
        )

# %%
spatialStep : float = 1e-2
temporalStep : float = (spatialStep ** 2) / 4
courantNumber : float = 1.0
pointCount : int = int(1 / spatialStep)
print(pointCount)
assert (temporalStep / spatialStep) <= courantNumber
profile = SimulationProfile(
        makeLinspaceGrid(pointCount, 1, 2, False, float, np), 
        lambda position : makeWavePacket(position, .8, 0.5, spatialStep, .05, 15 * np.pi, np), 
        lambda position, time : position.x * 0.0, #doubleSlit(position, .4, .1, .05, .0125, 20000), 
        temporalStep, 
        spatialStep, 
        False, 
        True
    )
simulator = Simulator(profile)
simulator.simulate(500, False)
probabilities, probabilityDecibles = simulator.processProbabilities()
# Out:
# 100

# %%
potentialAnimation = animateImages(pointCount, simulator.potentials)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
waveAnimation = animateImages(pointCount, simulator.probabilities, interval = 50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot([np.sum(probabilities) * (spatialStep ** 2) for probabilities in simulator.probabilities])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
results = np.array([sp.integrate.simps(sp.integrate.simps(((psi.real ** 2) + (psi.imag ** 2)), dx=spatialStep), dx=spatialStep) for psi in simulator.waveFunctions])

# %%
#plt.figure()
#plt.plot(results)

# %%
def double_Integral(xmin, xmax, ymin, ymax, nx, ny, A):

    dS = ((xmax-xmin)/(nx-1)) * ((ymax-ymin)/(ny-1))

    A_Internal = A[1:-1, 1:-1]

    # sides: up, down, left, right
    (A_u, A_d, A_l, A_r) = (A[0, 1:-1], A[-1, 1:-1], A[1:-1, 0], A[1:-1, -1])

    # corners
    (A_ul, A_ur, A_dl, A_dr) = (A[0, 0], A[0, -1], A[-1, 0], A[-1, -1])

    return dS * (np.sum(A_Internal)\
                + 0.5 * (np.sum(A_u) + np.sum(A_d) + np.sum(A_l) + np.sum(A_r))\
                + 0.25 * (A_ul + A_ur + A_dl + A_dr))

# %%
test = [double_Integral(
        0, 
        pointCount * spatialStep, 
        0, pointCount * spatialStep, 
        pointCount, 
        pointCount, 
        (psi.real ** 2) + (psi.imag ** 2)
    ) for psi in simulator.waveFunctions]

# %%
#plt.figure()
#plt.plot(test)

# %%
#value seems to be conserved though it is not 1

# %%
integrated = [(spatialStep ** 2) * np.sum(np.sum((psi.real ** 2) + (psi.imag ** 2))) for psi in simulator.waveFunctions]

# %%
plt.figure()
plt.plot(integrated)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(integrated)
# Out:
# [3.2478582909102925e-07, 3.2478582492516393e-07, 3.24785824925164e-07, 3.2478582492516404e-07, 3.24785824925164e-07, 3.2478582492516404e-07, 3.247858249251641e-07, 3.2478582492516404e-07, 3.24785824925164e-07, 3.24785824925164e-07, 3.247858249251641e-07, 3.247858249251641e-07, 3.2478582492516404e-07, 3.247858249251641e-07, 3.2478582492516414e-07, 3.2478582492516414e-07, 3.247858249251641e-07, 3.2478582492516414e-07, 3.2478582492516414e-07, 3.247858249251641e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.2478582492516414e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.2478582492516425e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.2478582492516425e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.2478582492516425e-07, 3.247858249251642e-07, 3.2478582492516425e-07, 3.247858249251642e-07, 3.2478582492516425e-07, 3.2478582492516425e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.247858249251642e-07, 3.2478582492516425e-07, 3.2478582492516425e-07, 3.247858249251642e-07, 3.247858249251643e-07, 3.2478582492516436e-07, 3.247858249251643e-07, 3.247858249251643e-07, 3.247858249251643e-07, 3.2478582492516436e-07, 3.247858249251643e-07, 3.2478582492516436e-07, 3.247858249251643e-07, 3.2478582492516436e-07, 3.247858249251644e-07, 3.2478582492516446e-07, 3.2478582492516436e-07, 3.2478582492516436e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.2478582492516446e-07, 3.247858249251645e-07, 3.2478582492516446e-07, 3.247858249251645e-07, 3.2478582492516457e-07, 3.247858249251645e-07, 3.2478582492516457e-07, 3.247858249251646e-07, 3.247858249251646e-07, 3.2478582492516467e-07, 3.2478582492516467e-07, 3.2478582492516467e-07, 3.2478582492516467e-07, 3.2478582492516467e-07, 3.2478582492516467e-07, 3.247858249251648e-07, 3.247858249251648e-07, 3.247858249251648e-07, 3.247858249251647e-07, 3.247858249251648e-07, 3.2478582492516483e-07, 3.247858249251648e-07, 3.247858249251649e-07, 3.2478582492516483e-07, 3.2478582492516483e-07, 3.2478582492516483e-07, 3.247858249251649e-07, 3.2478582492516494e-07, 3.247858249251649e-07, 3.2478582492516494e-07, 3.2478582492516494e-07, 3.2478582492516494e-07, 3.2478582492516494e-07, 3.2478582492516494e-07, 3.2478582492516494e-07, 3.2478582492516494e-07, 3.24785824925165e-07, 3.24785824925165e-07, 3.2478582492516494e-07, 3.24785824925165e-07, 3.2478582492516504e-07, 3.2478582492516504e-07, 3.2478582492516504e-07, 3.247858249251651e-07, 3.247858249251651e-07, 3.247858249251651e-07, 3.247858249251651e-07, 3.247858249251651e-07, 3.2478582492516515e-07, 3.247858249251651e-07, 3.2478582492516515e-07, 3.2478582492516515e-07, 3.2478582492516515e-07, 3.2478582492516515e-07, 3.2478582492516515e-07, 3.247858249251652e-07, 3.247858249251652e-07, 3.247858249251652e-07, 3.2478582492516526e-07, 3.2478582492516515e-07, 3.247858249251652e-07, 3.247858249251652e-07, 3.2478582492516526e-07, 3.2478582492516526e-07, 3.2478582492516526e-07, 3.2478582492516536e-07, 3.2478582492516526e-07, 3.247858249251653e-07, 3.2478582492516536e-07, 3.2478582492516536e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.247858249251654e-07, 3.2478582492516547e-07, 3.247858249251654e-07, 3.2478582492516547e-07, 3.2478582492516547e-07, 3.247858249251655e-07, 3.247858249251655e-07, 3.2478582492516557e-07, 3.247858249251655e-07, 3.2478582492516557e-07, 3.247858249251656e-07, 3.2478582492516557e-07, 3.247858249251656e-07, 3.2478582492516557e-07, 3.247858249251656e-07, 3.247858249251656e-07, 3.247858249251657e-07, 3.247858249251657e-07, 3.247858249251657e-07, 3.247858249251657e-07, 3.247858249251657e-07, 3.247858249251657e-07, 3.2478582492516573e-07, 3.247858249251 ...

# %%
np.sum(simulator.probabilities[0])
# Out:
# 1.0

# %%
np.max(simulator.probabilities[0])
# Out:
# 0.006457261127507643

# %%
np.sum(simulator.probabilities[1])
# Out:
# 1.0000274720631834

# %%
np.sum(simulator.probabilities[-1])
# Out:
# 4.010002187644315

# %%
np.max(simulator.probabilities[-1])
# Out:
# 0.0017135662390144833

# %%
plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.plot([np.sum(waveFunction.real) for waveFunction in simulator.waveFunctions])

# %%
plt.plot([np.sum(waveFunction.imag) for waveFunction in simulator.waveFunctions])

# %%
plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.plot([np.max(probabilitySet) for probabilitySet in simulator.probabilities])

# %%
#waveAnimation.save("low_res_slit_0.mp4")
