# %%
import numpy as np

# %%
import scipy.special as sps

# %%
from matplotlib import pyplot as plt

# %%
x = np.linspace(-1, 1, int(2e4))

# %%
p = x

# %%
y = sps.airy(x)[0]

# %%
plt.plot(x, y)

# %%
appx = (1 / np.sqrt(np.pi)) * ((1.0 / -x) ** (1.0 / 4.0)) * np.sin((np.pi / 4.0) + 2.0 * ((-x)**(2.0 / 3.0)) / 3.0)
# Out:
# /tmp/ipykernel_360/984494597.py:1: RuntimeWarning: invalid value encountered in power
#   appx = (1 / np.sqrt(np.pi)) * ((1.0 / -x) ** (1.0 / 4.0)) * np.sin((np.pi / 4.0) + 2.0 * ((-x)**(2.0 / 3.0)) / 3.0)

# %%
plt.plot(x, appx)
